# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/flats.csv")

# %%
df.sample(5)
# Out:
#       Unnamed: 0                    property_name  \
# 2455        2455  3 BHK Flat in Sector 92 Gurgaon
# 81            81  3 BHK Flat in Sector 89 Gurgaon
# 1861        1861  3 BHK Flat in Sector 65 Gurgaon
# 633          633  2 BHK Flat in Sector 85 Gurgaon
# 1826        1826  2 BHK Flat in sector 58 Gurgaon
#
#                                                    link  \
# 2455  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 81    https://www.99acres.com/3-bhk-bedroom-apartmen...
# 1861  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 633   https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1826  https://www.99acres.com/2-bhk-bedroom-apartmen...
#
#                                     society       price             area  \
# 2455                          Sare Petioles  1.25 Crore   ₹ 6,097/sq.ft.
# 81                            M3M Soulitude  1.25 Crore   ₹ 8,784/sq.ft.
# 1861  Emaar MGF Emerald Floors Premier3.8 ★   2.5 Crore  ₹ 15,151/sq.ft.
# 633                       Orris Aster Court   66.99 Lac   ₹ 5,825/sq.ft.
# 1826               Ireo The Grand Arch4.0 ★   2.2 Crore  ₹ 13,480/sq.ft.
#
#                                            areaWithType     bedRoom  \
# 2455                   Carpet area: 2050 (190.45 sq.m.)  3 Bedrooms
# 81    Built Up area: 1423 (132.2 sq.m.)Carpet area: ...  3 Bedrooms
# 1861             Super Built up area 1650(153.29 sq.m.)  3 Bedrooms
# 633   Super Built up area 1375(127.74 sq.m.)Built Up...  2 Bedrooms
# 1826  Super Built up area 1632(151.62 sq.m.)Built Up...  2 Bedrooms
#
#          bathroom      balcony  ...  \
# 2455  3 Bathrooms  3 Balconies  ...
# 81    3 Bathrooms   No Balcony  ...
# 1861  3 Bathrooms  3 Balconies  ...
# 633   2 Bathrooms  2 Balconies  ...
# 1826  2 Bathrooms    1 Balcony  ...
#
#                                                 address             floorNum  \
# 2455                Sector 92 Gurgaon, Gurgaon, Haryana  18th   of 20 Floors
# 81       Sector 89, Sector 89 Gurgaon, Gurgaon, Haryana    4th   of 4 Floors
# 1861                Sector 65 Gurgaon, Gurgaon, Haryana    3rd   of 5 Floors
# 633   501, Orris Aster Court Sector 85 Gurgaon, Sect...   5th   of 12 Floors
# 1826                sector 58 Gurgaon, Gurgaon, Haryana   5th   of 29 Floors
#
#           facing        agePossession  \
# 2455         NaN  2024-07-01 00:00:00
# 81           NaN            undefined
# 1861  South-West      1 to 5 Year Old
# 633   North-West      1 to 5 Year Old
# 1826  North-East      1 to 5 Year Old
#
#                                         nearbyLocations  \
# 2455  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 81    ['Vatika Town Square-INXT', 'Sector 86 Road', ...
# 1861  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 633   ['Proposed Metro Station', 'Dwarka Expressway'...
# 1826  ['Sector 55-56 Rapid Metro', 'Paras Trinity Ma...
#
#                                             description  \
# 2455  Under develop post nclt award to dhoot group 6...
# 81    Best in class property available at sector 89 ...
# 1861  Emerald floors premier 3bhk plus study plus sq...
# 633   This 2 bhk flat is located in orris aster cour...
# 1826  This beautiful 2 bhk flat in sector 58 gurgaon...
#
#                                          furnishDetails  \
# 2455                                                 []
# 81                                                  NaN
# 1861                                                 []
# 633   ['4 Fan', '1 Exhaust Fan', '1 Geyser', '15 Lig...
# 1826  ['6 Fan', '1 Exhaust Fan', '2 Geyser', '1 Stov...
#
#                                                features  \
# 2455  ['Security / Fire Alarm', 'Intercom Facility',...
# 81                                                  NaN
# 1861           ['Intercom Facility', 'Lift(s)', 'Park']
# 633   ['Centrally Air Conditioned', 'Water purifier'...
# 1826  ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                                  rating property_id
# 2455  ['Environment5 out of 5', 'Lifestyle4 out of 5...   Q69196420
# 81    ['Environment4 out of 5', 'Safety4 out of 5', ...   Q68653922
# 1861  ['Green Area4.5 out of 5', 'Construction5 out ...   R69102324
# 633   ['Environment5 out of 5', 'Lifestyle5 out of 5...   A64944642
# 1826  ['Green Area5 out of 5', 'Construction5 out of...   C69807488
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (3028, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3028 non-null   int64
#  1   property_name    3008 non-null   object
#  2   link             3008 non-null   object
#  3   society          3007 non-null   object
#  4   price            3007 non-null   object
#  5   area             2996 non-null   object
#  6   areaWithType     3008 non-null   object
#  7   bedRoom          3008 non-null   object
#  8   bathroom         3008 non-null   object
#  9   balcony          3008 non-null   object
#  10  additionalRoom   1694 non-null   object
#  11  address          3002 non-null   object
#  12  floorNum         3006 non-null   object
#  13  facing           2127 non-null   object
#  14  agePossession    3007 non-null   object
#  15  nearbyLocations  2913 non-null   object
#  16  description      3008 non-null   object
#  17  furnishDetails   2203 non-null   object
#  18  features         2594 non-null   object
#  19  rating           2676 non-null   object
#  20  property_id      3008 non-null   object
# dtypes: int64(1), object(20)
# memory usage: 496.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# property_name        20
# link                 20
# society              21
# price                21
# area                 32
# areaWithType         20
# bedRoom              20
# bathroom             20
# balcony              20
# additionalRoom     1334
# address              26
# floorNum             22
# facing              901
# agePossession        21
# nearbyLocations     115
# description          20
# furnishDetails      825
# features            434
# rating              352
# property_id          20
# dtype: int64

# %%
df.drop(columns=['link', 'property_id', 'Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# 2  2 Bathrooms  3 Balconies            NaN
# 3  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3  2023-12-01 00:00:00  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4   Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df.rename(columns={'area' : 'price_per_sqft'}, inplace=True)

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                             73
# Tulip Violet4.3 ★                            40
# Shapoorji Pallonji Joyville Gurugram4.0 ★    39
# Signature Global Park4.0 ★                   36
# Shree Vardhman Victoria3.8 ★                 35
#                                              ..
# Millenia                                      1
# Wings Apartment                               1
# Uphaar Residency 2                            1
# The Center Court                              1
# Divya Apartments                              1
# Name: count, Length: 636, dtype: int64

# %%
df['society'].value_counts().shape
# Out:
# (636,)

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].value_counts()
# Out:
# society
# tulip violet                            75
# ss the leaf                             74
# shapoorji pallonji joyville gurugram    45
# dlf new town heights                    38
# signature global park                   36
#                                         ..
# earth copia                              1
# bhemerlei                                1
# wings apartment                          1
# uphaar residency 2                       1
# the center court                         1
# Name: count, Length: 602, dtype: int64

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore    79
# 1.1 Crore     61
# 1.4 Crore     60
# 1.2 Crore     59
# 1.5 Crore     59
#               ..
# 26.9 Lac       1
# 26.5 Lac       1
# 73.53 Lac      1
# 89.77 Lac      1
# 62.5 Lac       1
# Name: count, Length: 439, dtype: int64

# %%
df[df['price'] == 'price on Request']
# Out:
# Empty DataFrame
# Columns: [property_name, society, price, price_per_sqft, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, floorNum, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating]
# Index: []

# %%
df = df[df['price'] != 'price on Request']

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# 2  2 Bathrooms  3 Balconies            NaN
# 3  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3  2023-12-01 00:00:00  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4   Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
def treat_price(x):
    if isinstance(x, float) or isinstance(x, int):
        return x

    if not isinstance(x, list):
        return None

    if len(x) < 2:
        return None

    value = x[0]
    unit = x[1].lower()
    try:
        value = float(value)
    except:
        return None

    if unit == "lac" or unit == "lakh":
        return round(value / 100, 2)

    if unit == "cr" or unit == "crore":
        return round(value, 2)

    return round(value, 2)

df['price'] = df['price'].str.split(' ').apply(treat_price)

# %%
df.head(5)
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# 2  2 Bathrooms  3 Balconies            NaN
# 3  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3  2023-12-01 00:00:00  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4   Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.    19
# ₹ 12,500/sq.ft.    16
# ₹ 8,000/sq.ft.     16
# ₹ 6,666/sq.ft.     13
# ₹ 5,000/sq.ft.     13
#                    ..
# ₹ 4,723/sq.ft.      1
# ₹ 6,129/sq.ft.      1
# ₹ 7,234/sq.ft.      1
# ₹ 8,823/sq.ft.      1
# ₹ 16,859/sq.ft.     1
# Name: count, Length: 2128, dtype: int64

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# 2  2 Bathrooms  3 Balconies            NaN
# 3  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3  2023-12-01 00:00:00  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4   Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 3 Bedrooms    1439
# 2 Bedrooms     948
# 4 Bedrooms     481
# 1 Bedroom      105
# 5 Bedrooms      32
# 6 Bedrooms       3
# Name: count, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
#      property_name society  price  price_per_sqft areaWithType bedRoom  \
# 286            NaN     nan    NaN             NaN          NaN     NaN
# 2850           NaN     nan    NaN             NaN          NaN     NaN
# 2851           NaN     nan    NaN             NaN          NaN     NaN
# 2852           NaN     nan    NaN             NaN          NaN     NaN
# 2853           NaN     nan    NaN             NaN          NaN     NaN
# 2923           NaN     nan    NaN             NaN          NaN     NaN
# 2924           NaN     nan    NaN             NaN          NaN     NaN
# 2925           NaN     nan    NaN             NaN          NaN     NaN
# 2927           NaN     nan    NaN             NaN          NaN     NaN
# 2928           NaN     nan    NaN             NaN          NaN     NaN
# 2994           NaN     nan    NaN             NaN          NaN     NaN
# 2995           NaN     nan    NaN             NaN          NaN     NaN
# 2996           NaN     nan    NaN             NaN          NaN     NaN
# 2997           NaN     nan    NaN             NaN          NaN     NaN
# 2998           NaN     nan    NaN             NaN          NaN     NaN
# 2999           NaN     nan    NaN             NaN          NaN     NaN
# 3000           NaN     nan    NaN             NaN          NaN     NaN
# 3001           NaN     nan    NaN             NaN          NaN     NaN
# 3002           NaN     nan    NaN             NaN          NaN     NaN
# 3003           NaN     nan    NaN             NaN          NaN     NaN
#
#      bathroom balcony additionalRoom address floorNum facing agePossession  \
# 286       NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2850      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2851      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2852      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2853      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2923      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2924      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2925      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2927      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2928      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2994      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2995      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2996      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2997      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2998      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 2999      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 3000      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 3001      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 3002      NaN     NaN            NaN     NaN      NaN    NaN           NaN
# 3003      NaN     NaN            NaN     NaN      NaN    NaN           NaN
#
#      nearbyLocations description furnishDetails features rating
# 286              NaN         NaN            NaN      NaN    NaN
# 2850             NaN         NaN            NaN      NaN    NaN
# 2851             NaN         NaN            NaN      NaN    NaN
# 2852             NaN         NaN            NaN      NaN    NaN
# 2853             NaN         NaN            NaN      NaN    NaN
# 2923             NaN         NaN            NaN      NaN    NaN
# 2924             NaN         NaN            NaN      NaN    NaN
# 2925             NaN         NaN            NaN      NaN    NaN
# 2927             NaN         NaN            NaN      NaN    NaN
# 2928             NaN         NaN            NaN      NaN    NaN
# 2994             NaN         NaN            NaN      NaN    NaN
# 2995             NaN         NaN            NaN      NaN    NaN
# 2996             NaN         NaN            NaN      NaN    NaN
# 2997             NaN         NaN            NaN      NaN    NaN
# 2998             NaN         NaN            NaN      NaN    NaN
# 2999             NaN         NaN            NaN      NaN    NaN
# 3000             NaN         NaN            NaN      NaN    NaN
# 3001             NaN         NaN            NaN      NaN    NaN
# 3002             NaN         NaN            NaN      NaN    NaN
# 3003             NaN         NaN            NaN      NaN    NaN

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# 2  2 Bathrooms  3 Balconies            NaN
# 3  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3  2023-12-01 00:00:00  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4   Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 2 Bathrooms    1047
# 3 Bathrooms     991
# 4 Bathrooms     638
# 5 Bathrooms     170
# 1 Bathroom      115
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#        balcony additionalRoom                              address  \
# 0    1 Balcony            NaN     Krishna Colony, Gurgaon, Haryana
# 1    1 Balcony            NaN   46b, Ashok Vihar, Gurgaon, Haryana
# 2  3 Balconies            NaN              Sohna, Gurgaon, Haryana
# 3  2 Balconies     Study Room  Sector 61 Gurgaon, Gurgaon, Haryana
# 4  3 Balconies     Study Room  Sector 92 Gurgaon, Gurgaon, Haryana
#
#               floorNum facing        agePossession  \
# 0    4th   of 4 Floors   West      1 to 5 Year Old
# 1    1st   of 3 Floors   West         10+ Year Old
# 2  12nd   of 14 Floors    NaN      0 to 1 Year Old
# 3    2nd   of 4 Floors    NaN  2023-12-01 00:00:00
# 4    5th   of 8 Floors    NaN   Under Construction
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  ['Huda City Metro', 'Golf Course extn road', '...
# 3  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df['additionalRoom'].isnull().sum()
# Out:
# np.int64(1314)

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# C:\Users\Ayushi\AppData\Local\Temp\ipykernel_24816\3584107056.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# 0       1  not available     Krishna Colony, Gurgaon, Haryana
# 1       1  not available   46b, Ashok Vihar, Gurgaon, Haryana
# 2       3  not available              Sohna, Gurgaon, Haryana
# 3       2     study room  Sector 61 Gurgaon, Gurgaon, Haryana
# 4       3     study room  Sector 92 Gurgaon, Gurgaon, Haryana
#
#               floorNum facing        agePossession  \
# 0    4th   of 4 Floors   West      1 to 5 Year Old
# 1    1st   of 3 Floors   West         10+ Year Old
# 2  12nd   of 14 Floors    NaN      0 to 1 Year Old
# 3    2nd   of 4 Floors    NaN  2023-12-01 00:00:00
# 4    5th   of 8 Floors    NaN   Under Construction
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  ['Huda City Metro', 'Golf Course extn road', '...
# 3  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df['floorNum']
# Out:
# 0         4th   of 4 Floors
# 1         1st   of 3 Floors
# 2       12nd   of 14 Floors
# 3         2nd   of 4 Floors
# 4         5th   of 8 Floors
#                ...
# 3023     9th   of 13 Floors
# 3024      4th   of 5 Floors
# 3025     3rd   of 22 Floors
# 3026      9th   of 9 Floors
# 3027     7th   of 36 Floors
# Name: floorNum, Length: 3008, dtype: object

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(2)

# %%
df[df['floorNum'].isnull()]
# Out:
#                                 property_name             society  price  \
# 181   3 BHK Flat in Dwarka Expressway Gurgaon  experion heartsong   1.08
# 2767          2 BHK Flat in Sector 78 Gurgaon                 nan   0.60
#
#       price_per_sqft                        areaWithType  bedRoom  bathroom  \
# 181           6150.0  Built Up area: 1758 (163.32 sq.m.)        3         3
# 2767          3692.0  Built Up area: 1625 (150.97 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 181        0  not available
# 2767       0  not available
#
#                                                 address floorNum facing  \
# 181   604, Tower B-3, 6th Floor,Sector 108, Dwarka E...      NaN    NaN
# 2767       Gurgaon, Sector 78 Gurgaon, Gurgaon, Haryana      NaN    NaN
#
#            agePossession nearbyLocations  \
# 181   Under Construction             NaN
# 2767  Under Construction             NaN
#
#                                             description furnishDetails  \
# 181   A property by one of the most reputed builders...             []
# 2767  The property is under construction it's by rah...             []
#
#      features                                             rating
# 181       NaN                                                NaN
# 2767      NaN  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address floorNum facing  \
# 0       1  not available     Krishna Colony, Gurgaon, Haryana        4   West
# 1       1  not available   46b, Ashok Vihar, Gurgaon, Haryana        1   West
# 2       3  not available              Sohna, Gurgaon, Haryana       12    NaN
# 3       2     study room  Sector 61 Gurgaon, Gurgaon, Haryana        2    NaN
# 4       3     study room  Sector 92 Gurgaon, Gurgaon, Haryana        5    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3  2023-12-01 00:00:00  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4   Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df['facing'].value_counts()
# Out:
# facing
# North-East    506
# East          492
# North         302
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].value_counts()
# Out:
# facing
# North-East    506
# East          492
# North         302
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(881)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# C:\Users\Ayushi\AppData\Local\Temp\ipykernel_24816\2381597952.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            881
# North-East    506
# East          492
# North         302
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# 0        2         2       1  not available
# 1        2         2       1  not available
# 2        2         2       3  not available
# 3        2         2       2     study room
# 4        2         2       3     study room
#
#                                address floorNum facing        agePossession  \
# 0     Krishna Colony, Gurgaon, Haryana        4   West      1 to 5 Year Old
# 1   46b, Ashok Vihar, Gurgaon, Haryana        1   West         10+ Year Old
# 2              Sohna, Gurgaon, Haryana       12     NA      0 to 1 Year Old
# 3  Sector 61 Gurgaon, Gurgaon, Haryana        2     NA  2023-12-01 00:00:00
# 4  Sector 92 Gurgaon, Gurgaon, Haryana        5     NA   Under Construction
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  ['Huda City Metro', 'Golf Course extn road', '...
# 3  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3008 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3008 non-null   object
#  1   property_type    3008 non-null   object
#  2   society          3008 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     3008 non-null   object
#  7   bedRoom          3008 non-null   int64
#  8   bathroom         3008 non-null   int64
#  9   balcony          3008 non-null   object
#  10  additionalRoom   3008 non-null   object
#  11  address          3002 non-null   object
#  12  floorNum         3006 non-null   object
#  13  facing           3008 non-null   object
#  14  agePossession    3007 non-null   object
#  15  nearbyLocations  2913 non-null   object
#  16  description      3008 non-null   object
#  17  furnishDetails   2203 non-null   object
#  18  features         2594 non-null   object
#  19  rating           2676 non-null   object
# dtypes: float64(3), int64(2), object(15)
# memory usage: 493.5+ KB

# %%
df.shape
# Out:
# (3008, 20)

# %%
df.to_csv('../data/flats_cleaned.csv',index=False)
